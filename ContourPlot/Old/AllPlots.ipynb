// %%
#include<cmath>

// %%
gROOT->ProcessLine(".x CVSReader.C");
// Out:
// (int) 0

// %%
/*XC pb and Lumi fb^{-1}*/
Double_t Significance(Double_t Lumi,Double_t XCSignal,Double_t EffSignal,std::vector<Double_t> XCBG,std::vector<Double_t> EffBG){
  
    if(XCBG.size() != EffBG.size()){
        std::cout<<  "ERROR: XCBG and EffBG should be same size" << std::endl;
        return 0;
    }
    Double_t TotalBG = 0;
    for (Int_t i=0;i<XCBG.size();i++){
        TotalBG += XCBG[i]*EffBG[i]*1000;//*1000 bp to fb
        //std::cout<<  TotalBG << std::endl;
    }
    Double_t Denominator = std::sqrt((XCSignal*EffSignal*1000+TotalBG)*Lumi);//*1000 bp to fb
    Double_t Numerator = XCSignal*EffSignal*Lumi*1000;
    Double_t Z = Numerator/Denominator;
    return Z;
}

// %%
//XC pb y lumi fb-1
Double_t Lumi(Double_t Z,Double_t XCSignal,Double_t EffSignal,std::vector<Double_t> XCBG,std::vector<Double_t> EffBG){
  
    if(XCBG.size() != EffBG.size()){
        std::cout<<  "ERROR: XCBG and EffBG should be same size" << std::endl;
        return 0;
    }
    Double_t TotalBG = 0;
    for (Int_t i=0;i<XCBG.size();i++){
        TotalBG += XCBG[i]*EffBG[i]*1000;//pb to fb
        //std::cout<< "XC: " <<XCBG[i] <<" , Eff: "<< EffBG[i]<< std::endl;
    }
    Double_t Numerator = ((EffSignal*XCSignal*1000)+TotalBG)*Z*Z;
    Double_t Denominator = (EffSignal*XCSignal*1000)*(EffSignal*XCSignal*1000);
    
    Double_t Lum = Numerator/Denominator;
    return Lum;
}

// %%
//Xs fb
Double_t Xs[]= {751.3, 633.5, 540.3, 460.3, 398.0, 343.3, 300.1, 262.3, 231.9, 203.9, 181.0, 161.1, 144.1, 128.9, 115.6, 103.8, 93.82, 84.97, 77.13};
Double_t MF[]= {100  , 105  , 110  , 115  , 120  , 125  , 130  , 135  , 140  , 145  , 150  , 155  , 160  , 165, 170, 175, 180, 185, 190};
// You can choose among the following methods:
// kLINEAR, kPOLYNOMIAL, kCSPLINE, kCSPLINE_PERIODIC, kAKIMA, kAKIMA_PERIODIC 
const Int_t ni = 19;//size of the arrays
ROOT::Math::Interpolator XS(ni, ROOT::Math::Interpolation::kLINEAR);
XS.SetData(ni, MF, Xs);

// %%
std::vector<Double_t> _XCBG;
std::vector<Double_t> _EffBG;
_XCBG.push_back(569.97800);//all
_EffBG.push_back(1);

// %%
5.6997800
// Out:
// (double) 5.6997800

// %%
// Creating an object of CSVWriter
CSVReader reader("EffVLF_BRmu25_BRtau75.csv");

// %%
// Get the data from CSV File
std::vector<std::vector<std::string> > dataList = reader.getData();

// %%
TCanvas *c1 = new TCanvas("c1","A Simple Graph Example",200,10,700,500);

// %%
Double_t MinY = 2;
Double_t MinX = 100;
Double_t MaxY = 21;
Double_t MaxX = 170;

// %%
gStyle->SetOptStat(0);
TH2D *h0 = new TH2D("h0","",14,MinX,MaxX,19,MinY,MaxY);
TH2D *h1 = new TH2D("h1","",14,MinX,MaxX,19,MinY,MaxY);
TH2D *h2 = new TH2D("h2","",14,MinX,MaxX,19,MinY,MaxY);
TH2D *h3 = new TH2D("h2","",14,MinX,MaxX,19,MinY,MaxY);
double contours[4];
std::vector<Double_t> FistRow;
std::vector<Double_t> FistCol;
int count1 = 0;
// Out:
// Warning in <TROOT::Append>: Replacing existing TH1: h2 (Potential memory leak).

// %%
auto Frame = c1->DrawFrame(MinX,MinY,MaxX,MaxY);
c1->SetRightMargin(0.15);
gStyle->SetPalette(55);
Frame->GetXaxis()->SetTitle("m_{F} [GeV]");
Frame->GetYaxis()->SetTitle("#DeltaM(F,DM) [GeV]");
Frame->GetYaxis()->CenterTitle("True");
Frame->GetYaxis()->SetTitleFont(42);
Frame->GetXaxis()->SetTitleFont(42);
Frame->GetYaxis()->SetTitleSize(0.04);
Frame->GetXaxis()->SetTitleSize(0.04);

// %%
TLatex *   tex = new TLatex(0.85,0.91,"BR(F#rightarrow #mu)= 25%, BR(F#rightarrow #tau)= 75%;");
tex->SetNDC();
tex->SetTextAlign(31);
tex->SetTextFont(42);
tex->SetTextSize(0.04);
tex->SetLineWidth(2);
//tex->Draw("Same");
TLatex *   tex1 = new TLatex(0.97,0.7,"Efficiency");
tex1->SetNDC();
tex1->SetTextAlign(31);
tex1->SetTextFont(42);
tex1->SetTextSize(0.04);
tex1->SetLineWidth(2);
tex1->SetTextAngle(90);
//tex1->Draw("Same");

// %%
//TLatex *   tex = new TLatex(0.9,0.91,"BR(F#rightarrow #mu)= 100%, 3000 fb^{-1}, 13 TeV");
TLatex *   tex2 = new TLatex(0.85,0.91,"BR(F#rightarrow #mu)= 25%, BR(F#rightarrow #tau)= 75%");
tex2->SetNDC();
tex2->SetTextAlign(31);
tex2->SetTextFont(42);
tex2->SetTextSize(0.04);
tex2->SetLineWidth(2);
//tex2->Draw("Same");
TLatex *   tex12 = new TLatex(0.97,0.7,"Cross Section [fb]");
tex12->SetNDC();
tex12->SetTextAlign(31);
tex12->SetTextFont(42);
tex12->SetTextSize(0.04);
tex12->SetLineWidth(2);
tex12->SetTextAngle(90);
//tex1->Draw("Same");

// %%
TLatex *   tex3 = new TLatex(0.85,0.91,"BR(F#rightarrow #mu)= 25%, BR(F#rightarrow #tau)= 75%; 3000 fb^{-1}");
tex3->SetNDC();
tex3->SetTextAlign(31);
tex3->SetTextFont(42);
tex3->SetTextSize(0.04);
tex3->SetLineWidth(2);
//tex3->Draw("Same");
TLatex *   tex13 = new TLatex(0.97,0.8,"Number of Events after Cuts #times 1000");
tex13->SetNDC();
tex13->SetTextAlign(31);
tex13->SetTextFont(42);
tex13->SetTextSize(0.04);
tex13->SetLineWidth(2);
tex13->SetTextAngle(90);
//tex1->Draw("Same");

// %%
TLatex *   tex4 = new TLatex(0.85,0.91,"BR(F#rightarrow #mu)= 25%, BR(F#rightarrow #tau)= 75%; 3000 fb^{-1}, 13 TeV");
tex4->SetNDC();
tex4->SetTextAlign(31);
tex4->SetTextFont(42);
tex4->SetTextSize(0.04);
tex4->SetLineWidth(2);
//tex3->Draw("Same");
TLatex *   tex14 = new TLatex(0.97,0.7,"Significance #sigma = S/#sqrt{S+B}");
tex14->SetNDC();
tex14->SetTextAlign(31);
tex14->SetTextFont(42);
tex14->SetTextSize(0.04);
tex14->SetLineWidth(2);
tex14->SetTextAngle(90);
//tex1->Draw("Same");

// %%
//gStyle->SetPaintTextFormat("4.1f m");
gStyle->SetPaintTextFormat("1.4f");

// %%
// Print the content of row by row on screen
count1 = 0; 
for(std::vector<std::string> vec : dataList){
    int count2 = 0;
    for(std::string Data : vec){
        Double_t data = atof(Data.c_str());
        if (count1 == 0){
            FistRow.push_back(data);
        }else{
            if (count2 == 0){
                FistCol.push_back(data);
            }else{
                if(data != 0){//To be sure dont use the 0s
                    //h1->SetBinContent(FistCol.back(),FistRow[count2],data);
                    Double_t Z = Significance(3000.0,XS.Eval((Double_t)FistRow[count2])*0.001,data,_XCBG,_EffBG);//4* to put BR(mu)=100%
                    //h1->Fill(FistCol.back(),FistRow[count2],Z);
                    //std::cout<<"("<< FistCol.back() << ",";
                    h0->Fill(FistRow[count2],FistCol.back(),data);
                    h1->Fill(FistRow[count2],FistCol.back(),XS.Eval((Double_t)FistRow[count2]));
                    h2->Fill(FistRow[count2],FistCol.back(),XS.Eval((Double_t)FistRow[count2])*data*3.0);//3.0 -> 3000 fb-1
                    h3->Fill(FistRow[count2],FistCol.back(),Z);
                    //std::cout<<FistRow[count2] << ",";
                    //std::cout<<data << ") , ";     
                    }//else{//Deberia extrapolar entre los que o tengo}
                }  
            
        }
        count2++;
    }
    count1++;
    //std::cout<<std::endl;
    //std::cout<<std::endl;
}

// %%
h0->DrawCopy("colz same");
h0->DrawCopy("TEXT same");
tex1->Draw("Same");
tex->Draw("Same");
c1->Draw()

// %%
string Name = "";
string NameC = "";
string NamePDF = "";

// %%
Name = "Efficiency_BRmu25tau75";
NameC = Name+".C";
NamePDF = Name+".pdf";
//c1->SaveSource(NameC.c_str());
c1->SaveAs(NamePDF.c_str(),"pdf");
// Out:
// Info in <TCanvas::Print>: pdf file Efficiency_BRmu25tau75.pdf has been created

// %%
//c1->Clear();
gStyle->SetPaintTextFormat("1.2f");

// %%
h1->DrawCopy("colz");
h1->DrawCopy("TEXT same");
tex12->Draw("Same");
tex2->Draw("Same");
c1->Draw()

// %%
Name = "CrossSection_BRmu25tau75";
NameC = Name+".C";
NamePDF = Name+".pdf";
//c1->SaveSource(NameC.c_str());
//c1->SaveAs(NamePDF.c_str(),"pdf");

// %%
h2->DrawCopy("colz");
h2->DrawCopy("TEXT same");
tex13->Draw("Same");
tex3->Draw("Same");
c1->Draw()

// %%
Name = "NumberOfEventsAfterCuts_BRmu25tau75_3000fb-1";
NameC = Name+".C";
NamePDF = Name+".pdf";
//c1->SaveSource(NameC.c_str());
//c1->SaveAs(NamePDF.c_str(),"pdf");

// %%
h3->DrawCopy("colz");
h3->DrawCopy("TEXT same");
tex14->Draw("Same");
tex4->Draw("Same");
c1->Draw()

// %%
camilo = 10
// Out:
// (int) 10
