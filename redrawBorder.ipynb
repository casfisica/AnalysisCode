// %%
void redrawBorder()
{
   // this little macro redraws the axis tick marks and the pad border lines.
   gPad->Update();
   gPad->RedrawAxis();
   TLine l;
   l.DrawLine(gPad->GetUxmin(), gPad->GetUymax(), gPad->GetUxmax(), gPad->GetUymax());
   l.DrawLine(gPad->GetUxmax(), gPad->GetUymin(), gPad->GetUxmax(), gPad->GetUymax());
}

// %%
TCanvas *Canvas_muon1Pt_Cut0 = new TCanvas("Canvas_muon1Pt_Cut0", "Canvas_muon1Pt_Cut0",305,121,800,600);
   Canvas_muon1Pt_Cut0->SetHighLightColor(2);
   Canvas_muon1Pt_Cut0->Range(-15.60975,1.745399,81.95122,9.423098);
   Canvas_muon1Pt_Cut0->SetFillColor(0);
   Canvas_muon1Pt_Cut0->SetBorderMode(0);
   Canvas_muon1Pt_Cut0->SetBorderSize(2);
   Canvas_muon1Pt_Cut0->SetLogy();
   Canvas_muon1Pt_Cut0->SetTickx(1);
   Canvas_muon1Pt_Cut0->SetTicky(1);
   Canvas_muon1Pt_Cut0->SetLeftMargin(0.12);
   Canvas_muon1Pt_Cut0->SetRightMargin(0.04);
   Canvas_muon1Pt_Cut0->SetTopMargin(0.09);
   Canvas_muon1Pt_Cut0->SetBottomMargin(0.14);
   Canvas_muon1Pt_Cut0->SetFrameFillStyle(0);
   Canvas_muon1Pt_Cut0->SetFrameBorderMode(0);
   Canvas_muon1Pt_Cut0->SetFrameFillStyle(0);
   Canvas_muon1Pt_Cut0->SetFrameBorderMode(0);

// %%
   THStack *Stack_muon1Pt_Cut0 = new THStack();
   Stack_muon1Pt_Cut0->SetName("Stack_muon1Pt_Cut0");
   Stack_muon1Pt_Cut0->SetTitle("");
   
   TH1F *Stack_muon1Pt_Cut0_stack_1 = new TH1F("Stack_muon1Pt_Cut0_stack_1","",40,0,80);
   Stack_muon1Pt_Cut0_stack_1->SetMinimum(1.1e+3);
   Stack_muon1Pt_Cut0_stack_1->SetMaximum(1.0e+09);
   Stack_muon1Pt_Cut0_stack_1->SetDirectory(0);
   Stack_muon1Pt_Cut0_stack_1->SetStats(0);
   Stack_muon1Pt_Cut0_stack_1->SetLineStyle(0);
   Stack_muon1Pt_Cut0_stack_1->SetMarkerStyle(20);
   Stack_muon1Pt_Cut0_stack_1->GetXaxis()->SetTitle("p_{T}(#mu_{1}) [GeV]");
   Stack_muon1Pt_Cut0_stack_1->GetXaxis()->SetLabelFont(42);
   Stack_muon1Pt_Cut0_stack_1->GetXaxis()->SetLabelOffset(0.007);
   Stack_muon1Pt_Cut0_stack_1->GetXaxis()->SetLabelSize(0.05);
   Stack_muon1Pt_Cut0_stack_1->GetXaxis()->SetTitleSize(0.06);
   Stack_muon1Pt_Cut0_stack_1->GetXaxis()->SetTitleOffset(0.9);
   Stack_muon1Pt_Cut0_stack_1->GetXaxis()->SetTitleFont(42);
   Stack_muon1Pt_Cut0_stack_1->GetYaxis()->SetRange(1,1);
   Stack_muon1Pt_Cut0_stack_1->GetYaxis()->SetTitle("Events");
   Stack_muon1Pt_Cut0_stack_1->GetYaxis()->SetLabelFont(42);
   Stack_muon1Pt_Cut0_stack_1->GetYaxis()->SetLabelOffset(0.007);
   Stack_muon1Pt_Cut0_stack_1->GetYaxis()->SetLabelSize(0.05);
   Stack_muon1Pt_Cut0_stack_1->GetYaxis()->SetTitleSize(0.06);
   Stack_muon1Pt_Cut0_stack_1->GetYaxis()->SetTitleOffset(0.9);
   Stack_muon1Pt_Cut0_stack_1->GetYaxis()->SetTitleFont(42);
   Stack_muon1Pt_Cut0_stack_1->GetZaxis()->SetLabelFont(42);
   Stack_muon1Pt_Cut0_stack_1->GetZaxis()->SetLabelOffset(0.007);
   Stack_muon1Pt_Cut0_stack_1->GetZaxis()->SetLabelSize(0.05);
   Stack_muon1Pt_Cut0_stack_1->GetZaxis()->SetTitleSize(0.06);
   Stack_muon1Pt_Cut0_stack_1->GetZaxis()->SetTitleFont(42);
   Stack_muon1Pt_Cut0->SetHistogram(Stack_muon1Pt_Cut0_stack_1);
   
   
   TH1F *TT_muon1Pt_Cut0_stack_1 = new TH1F("TT_muon1Pt_Cut0_stack_1","",40,0,80);
   TT_muon1Pt_Cut0_stack_1->SetBinContent(2,2741323);
   TT_muon1Pt_Cut0_stack_1->SetBinContent(3,7691351);
   TT_muon1Pt_Cut0_stack_1->SetBinContent(4,4618601);
   TT_muon1Pt_Cut0_stack_1->SetBinContent(5,3937457);
   TT_muon1Pt_Cut0_stack_1->SetBinContent(6,3676546);
   TT_muon1Pt_Cut0_stack_1->SetBinContent(7,3199900);
   TT_muon1Pt_Cut0_stack_1->SetBinContent(8,2836741);
   TT_muon1Pt_Cut0_stack_1->SetBinContent(9,2683808);
   TT_muon1Pt_Cut0_stack_1->SetBinContent(10,2404167);
   TT_muon1Pt_Cut0_stack_1->SetBinContent(11,2403726);
   TT_muon1Pt_Cut0_stack_1->SetBinContent(12,2199229);
   TT_muon1Pt_Cut0_stack_1->SetBinContent(13,2080894);
   TT_muon1Pt_Cut0_stack_1->SetBinContent(14,1906806);
   TT_muon1Pt_Cut0_stack_1->SetBinContent(15,1815796);
   TT_muon1Pt_Cut0_stack_1->SetBinContent(16,1734923);
   TT_muon1Pt_Cut0_stack_1->SetBinContent(17,1658236);
   TT_muon1Pt_Cut0_stack_1->SetBinContent(18,1656914);
   TT_muon1Pt_Cut0_stack_1->SetBinContent(19,1646116);
   TT_muon1Pt_Cut0_stack_1->SetBinContent(20,1616808);
   TT_muon1Pt_Cut0_stack_1->SetBinContent(21,1549817);
   TT_muon1Pt_Cut0_stack_1->SetBinContent(22,1509050);
   TT_muon1Pt_Cut0_stack_1->SetBinContent(23,1449772);
   TT_muon1Pt_Cut0_stack_1->SetBinContent(24,1446467);
   TT_muon1Pt_Cut0_stack_1->SetBinContent(25,1429499);
   TT_muon1Pt_Cut0_stack_1->SetBinContent(26,1334522);
   TT_muon1Pt_Cut0_stack_1->SetBinContent(27,1273481);
   TT_muon1Pt_Cut0_stack_1->SetBinContent(28,1260700);
   TT_muon1Pt_Cut0_stack_1->SetBinContent(29,1216407);
   TT_muon1Pt_Cut0_stack_1->SetBinContent(30,1173877);
   TT_muon1Pt_Cut0_stack_1->SetBinContent(31,1096089);
   TT_muon1Pt_Cut0_stack_1->SetBinContent(32,1050914);
   TT_muon1Pt_Cut0_stack_1->SetBinContent(33,1022267);
   TT_muon1Pt_Cut0_stack_1->SetBinContent(34,974668.2);
   TT_muon1Pt_Cut0_stack_1->SetBinContent(35,924645.8);
   TT_muon1Pt_Cut0_stack_1->SetBinContent(36,860740.2);
   TT_muon1Pt_Cut0_stack_1->SetBinContent(37,802784.6);
   TT_muon1Pt_Cut0_stack_1->SetBinContent(38,778544.6);
   TT_muon1Pt_Cut0_stack_1->SetBinContent(39,728081.4);
   TT_muon1Pt_Cut0_stack_1->SetBinContent(40,721470.5);
   TT_muon1Pt_Cut0_stack_1->SetBinContent(41,1.100606e+07);
   TT_muon1Pt_Cut0_stack_1->SetBinError(2,24578.2);
   TT_muon1Pt_Cut0_stack_1->SetBinError(3,41169.09);
   TT_muon1Pt_Cut0_stack_1->SetBinError(4,31902.53);
   TT_muon1Pt_Cut0_stack_1->SetBinError(5,29456.28);
   TT_muon1Pt_Cut0_stack_1->SetBinError(6,28463.61);
   TT_muon1Pt_Cut0_stack_1->SetBinError(7,26554.5);
   TT_muon1Pt_Cut0_stack_1->SetBinError(8,25002.29);
   TT_muon1Pt_Cut0_stack_1->SetBinError(9,24319);
   TT_muon1Pt_Cut0_stack_1->SetBinError(10,23017.19);
   TT_muon1Pt_Cut0_stack_1->SetBinError(11,23015.08);
   TT_muon1Pt_Cut0_stack_1->SetBinError(12,22014.31);
   TT_muon1Pt_Cut0_stack_1->SetBinError(13,21413.86);
   TT_muon1Pt_Cut0_stack_1->SetBinError(14,20498.55);
   TT_muon1Pt_Cut0_stack_1->SetBinError(15,20003.38);
   TT_muon1Pt_Cut0_stack_1->SetBinError(16,19552.85);
   TT_muon1Pt_Cut0_stack_1->SetBinError(17,19115.83);
   TT_muon1Pt_Cut0_stack_1->SetBinError(18,19108.21);
   TT_muon1Pt_Cut0_stack_1->SetBinError(19,19045.84);
   TT_muon1Pt_Cut0_stack_1->SetBinError(20,18875.53);
   TT_muon1Pt_Cut0_stack_1->SetBinError(21,18480.35);
   TT_muon1Pt_Cut0_stack_1->SetBinError(22,18235.67);
   TT_muon1Pt_Cut0_stack_1->SetBinError(23,17873.92);
   TT_muon1Pt_Cut0_stack_1->SetBinError(24,17853.53);
   TT_muon1Pt_Cut0_stack_1->SetBinError(25,17748.51);
   TT_muon1Pt_Cut0_stack_1->SetBinError(26,17148.76);
   TT_muon1Pt_Cut0_stack_1->SetBinError(27,16751.98);
   TT_muon1Pt_Cut0_stack_1->SetBinError(28,16667.71);
   TT_muon1Pt_Cut0_stack_1->SetBinError(29,16372.29);
   TT_muon1Pt_Cut0_stack_1->SetBinError(30,16083.52);
   TT_muon1Pt_Cut0_stack_1->SetBinError(31,15541.49);
   TT_muon1Pt_Cut0_stack_1->SetBinError(32,15217.86);
   TT_muon1Pt_Cut0_stack_1->SetBinError(33,15009.01);
   TT_muon1Pt_Cut0_stack_1->SetBinError(34,14655.42);
   TT_muon1Pt_Cut0_stack_1->SetBinError(35,14274.39);
   TT_muon1Pt_Cut0_stack_1->SetBinError(36,13772.29);
   TT_muon1Pt_Cut0_stack_1->SetBinError(37,13300.55);
   TT_muon1Pt_Cut0_stack_1->SetBinError(38,13098.2);
   TT_muon1Pt_Cut0_stack_1->SetBinError(39,12666.6);
   TT_muon1Pt_Cut0_stack_1->SetBinError(40,12608.96);
   TT_muon1Pt_Cut0_stack_1->SetBinError(41,49247.69);
   TT_muon1Pt_Cut0_stack_1->SetEntries(390805);
   TT_muon1Pt_Cut0_stack_1->SetDirectory(0);

   Int_t ci;      // for color index setting
   TColor *color; // for color definition with alpha
   ci = TColor::GetColor("#ff0000");
   TT_muon1Pt_Cut0_stack_1->SetFillColor(ci);

   ci = TColor::GetColor("#ff0000");
   TT_muon1Pt_Cut0_stack_1->SetLineColor(ci);
   TT_muon1Pt_Cut0_stack_1->SetLineWidth(2);
   TT_muon1Pt_Cut0_stack_1->GetXaxis()->SetTitle("p_{T}(#mu_{1}) [GeV]");
   TT_muon1Pt_Cut0_stack_1->GetXaxis()->SetLabelFont(42);
   TT_muon1Pt_Cut0_stack_1->GetXaxis()->SetLabelOffset(0.007);
   TT_muon1Pt_Cut0_stack_1->GetXaxis()->SetLabelSize(0.05);
   TT_muon1Pt_Cut0_stack_1->GetXaxis()->SetTitleSize(0.06);
   TT_muon1Pt_Cut0_stack_1->GetXaxis()->SetTitleOffset(0.9);
   TT_muon1Pt_Cut0_stack_1->GetXaxis()->SetTitleFont(42);
   TT_muon1Pt_Cut0_stack_1->GetYaxis()->SetLabelFont(42);
   TT_muon1Pt_Cut0_stack_1->GetYaxis()->SetLabelOffset(0.007);
   TT_muon1Pt_Cut0_stack_1->GetYaxis()->SetLabelSize(0.05);
   TT_muon1Pt_Cut0_stack_1->GetYaxis()->SetTitleSize(0.06);
   TT_muon1Pt_Cut0_stack_1->GetYaxis()->SetTitleOffset(1.25);
   TT_muon1Pt_Cut0_stack_1->GetYaxis()->SetTitleFont(42);
   TT_muon1Pt_Cut0_stack_1->GetZaxis()->SetLabelFont(42);
   TT_muon1Pt_Cut0_stack_1->GetZaxis()->SetLabelOffset(0.007);
   TT_muon1Pt_Cut0_stack_1->GetZaxis()->SetLabelSize(0.05);
   TT_muon1Pt_Cut0_stack_1->GetZaxis()->SetTitleSize(0.06);
   TT_muon1Pt_Cut0_stack_1->GetZaxis()->SetTitleFont(42);
   Stack_muon1Pt_Cut0->Add(TT_muon1Pt_Cut0_stack_1,"");
   
   TH1F *FullWJets_muon1Pt_Cut0_stack_2 = new TH1F("FullWJets_muon1Pt_Cut0_stack_2","",40,0,80);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinContent(2,1.070193e+08);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinContent(3,2.212596e+08);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinContent(4,7.525245e+07);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinContent(5,5.10056e+07);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinContent(6,5.67278e+07);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinContent(7,6.15134e+07);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinContent(8,6.876174e+07);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinContent(9,7.88364e+07);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinContent(10,8.144202e+07);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinContent(11,9.128474e+07);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinContent(12,9.089781e+07);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinContent(13,8.923085e+07);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinContent(14,8.632179e+07);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinContent(15,8.001026e+07);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinContent(16,7.721968e+07);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinContent(17,7.239829e+07);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinContent(18,7.001445e+07);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinContent(19,6.881486e+07);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinContent(20,6.684072e+07);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinContent(21,5.989329e+07);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinContent(22,5.327824e+07);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinContent(23,4.791875e+07);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinContent(24,4.393409e+07);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinContent(25,4.052736e+07);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinContent(26,3.205054e+07);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinContent(27,2.725687e+07);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinContent(28,2.313853e+07);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinContent(29,1.956827e+07);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinContent(30,1.715132e+07);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinContent(31,1.438898e+07);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinContent(32,1.264999e+07);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinContent(33,1.154064e+07);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinContent(34,9888545);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinContent(35,9133317);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinContent(36,8077753);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinContent(37,7358657);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinContent(38,6609496);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinContent(39,5740258);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinContent(40,5438950);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinContent(41,7.003458e+07);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinError(2,919462.8);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinError(3,1320539);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinError(4,724153.9);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinError(5,554491.8);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinError(6,571964.8);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinError(7,578569.9);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinError(8,620423.3);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinError(9,675521.5);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinError(10,684901.3);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinError(11,722967.6);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinError(12,724505.2);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinError(13,727603.3);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinError(14,735680.1);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinError(15,722526.2);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinError(16,737669.1);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinError(17,740830.7);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinError(18,760386.3);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinError(19,797128.9);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinError(20,810047);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinError(21,769131.7);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinError(22,701005.2);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinError(23,647134.8);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinError(24,602769.4);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinError(25,563753.8);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinError(26,461104.2);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinError(27,410767.7);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinError(28,367235);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinError(29,330409.9);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinError(30,308024.9);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinError(31,271175.5);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinError(32,255106.7);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinError(33,242511.2);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinError(34,223155.1);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinError(35,211509.6);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinError(36,197049.9);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinError(37,190910.2);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinError(38,178093.7);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinError(39,163087.5);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinError(40,161135.7);
   FullWJets_muon1Pt_Cut0_stack_2->SetBinError(41,565479);
   FullWJets_muon1Pt_Cut0_stack_2->SetEntries(411100);
   FullWJets_muon1Pt_Cut0_stack_2->SetDirectory(0);

   ci = TColor::GetColor("#0000ff");
   FullWJets_muon1Pt_Cut0_stack_2->SetFillColor(ci);

   ci = TColor::GetColor("#0000ff");
   FullWJets_muon1Pt_Cut0_stack_2->SetLineColor(ci);
   FullWJets_muon1Pt_Cut0_stack_2->SetLineWidth(2);
   FullWJets_muon1Pt_Cut0_stack_2->GetXaxis()->SetTitle("p_{T}(#mu_{1}) [GeV]");
   FullWJets_muon1Pt_Cut0_stack_2->GetXaxis()->SetLabelFont(42);
   FullWJets_muon1Pt_Cut0_stack_2->GetXaxis()->SetLabelOffset(0.007);
   FullWJets_muon1Pt_Cut0_stack_2->GetXaxis()->SetLabelSize(0.05);
   FullWJets_muon1Pt_Cut0_stack_2->GetXaxis()->SetTitleSize(0.06);
   FullWJets_muon1Pt_Cut0_stack_2->GetXaxis()->SetTitleOffset(0.9);
   FullWJets_muon1Pt_Cut0_stack_2->GetXaxis()->SetTitleFont(42);
   FullWJets_muon1Pt_Cut0_stack_2->GetYaxis()->SetLabelFont(42);
   FullWJets_muon1Pt_Cut0_stack_2->GetYaxis()->SetLabelOffset(0.007);
   FullWJets_muon1Pt_Cut0_stack_2->GetYaxis()->SetLabelSize(0.05);
   FullWJets_muon1Pt_Cut0_stack_2->GetYaxis()->SetTitleSize(0.06);
   FullWJets_muon1Pt_Cut0_stack_2->GetYaxis()->SetTitleOffset(1.25);
   FullWJets_muon1Pt_Cut0_stack_2->GetYaxis()->SetTitleFont(42);
   FullWJets_muon1Pt_Cut0_stack_2->GetZaxis()->SetLabelFont(42);
   FullWJets_muon1Pt_Cut0_stack_2->GetZaxis()->SetLabelOffset(0.007);
   FullWJets_muon1Pt_Cut0_stack_2->GetZaxis()->SetLabelSize(0.05);
   FullWJets_muon1Pt_Cut0_stack_2->GetZaxis()->SetTitleSize(0.06);
   FullWJets_muon1Pt_Cut0_stack_2->GetZaxis()->SetTitleFont(42);
   Stack_muon1Pt_Cut0->Add(FullWJets_muon1Pt_Cut0_stack_2,"");
   
   TH1F *FullDY_muon1Pt_Cut0_stack_3 = new TH1F("FullDY_muon1Pt_Cut0_stack_3","",40,0,80);
   FullDY_muon1Pt_Cut0_stack_3->SetBinContent(2,9969506);
   FullDY_muon1Pt_Cut0_stack_3->SetBinContent(3,2.242861e+07);
   FullDY_muon1Pt_Cut0_stack_3->SetBinContent(4,9850706);
   FullDY_muon1Pt_Cut0_stack_3->SetBinContent(5,6478784);
   FullDY_muon1Pt_Cut0_stack_3->SetBinContent(6,5550874);
   FullDY_muon1Pt_Cut0_stack_3->SetBinContent(7,4928785);
   FullDY_muon1Pt_Cut0_stack_3->SetBinContent(8,4368257);
   FullDY_muon1Pt_Cut0_stack_3->SetBinContent(9,4309261);
   FullDY_muon1Pt_Cut0_stack_3->SetBinContent(10,3870790);
   FullDY_muon1Pt_Cut0_stack_3->SetBinContent(11,3751396);
   FullDY_muon1Pt_Cut0_stack_3->SetBinContent(12,3401048);
   FullDY_muon1Pt_Cut0_stack_3->SetBinContent(13,3286254);
   FullDY_muon1Pt_Cut0_stack_3->SetBinContent(14,2934701);
   FullDY_muon1Pt_Cut0_stack_3->SetBinContent(15,2739398);
   FullDY_muon1Pt_Cut0_stack_3->SetBinContent(16,2591334);
   FullDY_muon1Pt_Cut0_stack_3->SetBinContent(17,2489918);
   FullDY_muon1Pt_Cut0_stack_3->SetBinContent(18,2450640);
   FullDY_muon1Pt_Cut0_stack_3->SetBinContent(19,2272786);
   FullDY_muon1Pt_Cut0_stack_3->SetBinContent(20,2143083);
   FullDY_muon1Pt_Cut0_stack_3->SetBinContent(21,1888711);
   FullDY_muon1Pt_Cut0_stack_3->SetBinContent(22,1707614);
   FullDY_muon1Pt_Cut0_stack_3->SetBinContent(23,1483236);
   FullDY_muon1Pt_Cut0_stack_3->SetBinContent(24,1286211);
   FullDY_muon1Pt_Cut0_stack_3->SetBinContent(25,1199625);
   FullDY_muon1Pt_Cut0_stack_3->SetBinContent(26,993909.5);
   FullDY_muon1Pt_Cut0_stack_3->SetBinContent(27,839252.9);
   FullDY_muon1Pt_Cut0_stack_3->SetBinContent(28,690686.4);
   FullDY_muon1Pt_Cut0_stack_3->SetBinContent(29,637533.1);
   FullDY_muon1Pt_Cut0_stack_3->SetBinContent(30,546483.8);
   FullDY_muon1Pt_Cut0_stack_3->SetBinContent(31,464888.2);
   FullDY_muon1Pt_Cut0_stack_3->SetBinContent(32,436426);
   FullDY_muon1Pt_Cut0_stack_3->SetBinContent(33,375452.9);
   FullDY_muon1Pt_Cut0_stack_3->SetBinContent(34,319918);
   FullDY_muon1Pt_Cut0_stack_3->SetBinContent(35,286809.3);
   FullDY_muon1Pt_Cut0_stack_3->SetBinContent(36,263905.8);
   FullDY_muon1Pt_Cut0_stack_3->SetBinContent(37,238556.6);
   FullDY_muon1Pt_Cut0_stack_3->SetBinContent(38,218066.8);
   FullDY_muon1Pt_Cut0_stack_3->SetBinContent(39,204226);
   FullDY_muon1Pt_Cut0_stack_3->SetBinContent(40,189013.4);
   FullDY_muon1Pt_Cut0_stack_3->SetBinContent(41,2498390);
   FullDY_muon1Pt_Cut0_stack_3->SetBinError(2,139235.3);
   FullDY_muon1Pt_Cut0_stack_3->SetBinError(3,214728.2);
   FullDY_muon1Pt_Cut0_stack_3->SetBinError(4,145194);
   FullDY_muon1Pt_Cut0_stack_3->SetBinError(5,110904.3);
   FullDY_muon1Pt_Cut0_stack_3->SetBinError(6,96042.88);
   FullDY_muon1Pt_Cut0_stack_3->SetBinError(7,87544.77);
   FullDY_muon1Pt_Cut0_stack_3->SetBinError(8,78350.52);
   FullDY_muon1Pt_Cut0_stack_3->SetBinError(9,77126.35);
   FullDY_muon1Pt_Cut0_stack_3->SetBinError(10,73259.34);
   FullDY_muon1Pt_Cut0_stack_3->SetBinError(11,67860.15);
   FullDY_muon1Pt_Cut0_stack_3->SetBinError(12,64372.37);
   FullDY_muon1Pt_Cut0_stack_3->SetBinError(13,64512.75);
   FullDY_muon1Pt_Cut0_stack_3->SetBinError(14,58683.51);
   FullDY_muon1Pt_Cut0_stack_3->SetBinError(15,56572.48);
   FullDY_muon1Pt_Cut0_stack_3->SetBinError(16,56933.02);
   FullDY_muon1Pt_Cut0_stack_3->SetBinError(17,56954.76);
   FullDY_muon1Pt_Cut0_stack_3->SetBinError(18,55189.8);
   FullDY_muon1Pt_Cut0_stack_3->SetBinError(19,54686.61);
   FullDY_muon1Pt_Cut0_stack_3->SetBinError(20,54290.74);
   FullDY_muon1Pt_Cut0_stack_3->SetBinError(21,49909.38);
   FullDY_muon1Pt_Cut0_stack_3->SetBinError(22,47803.94);
   FullDY_muon1Pt_Cut0_stack_3->SetBinError(23,43991.38);
   FullDY_muon1Pt_Cut0_stack_3->SetBinError(24,38267.58);
   FullDY_muon1Pt_Cut0_stack_3->SetBinError(25,37177.13);
   FullDY_muon1Pt_Cut0_stack_3->SetBinError(26,32109.33);
   FullDY_muon1Pt_Cut0_stack_3->SetBinError(27,29144.34);
   FullDY_muon1Pt_Cut0_stack_3->SetBinError(28,25327.83);
   FullDY_muon1Pt_Cut0_stack_3->SetBinError(29,25047.42);
   FullDY_muon1Pt_Cut0_stack_3->SetBinError(30,22094.09);
   FullDY_muon1Pt_Cut0_stack_3->SetBinError(31,18875.83);
   FullDY_muon1Pt_Cut0_stack_3->SetBinError(32,18469.82);
   FullDY_muon1Pt_Cut0_stack_3->SetBinError(33,19278.49);
   FullDY_muon1Pt_Cut0_stack_3->SetBinError(34,15088.08);
   FullDY_muon1Pt_Cut0_stack_3->SetBinError(35,15432.49);
   FullDY_muon1Pt_Cut0_stack_3->SetBinError(36,12944.98);
   FullDY_muon1Pt_Cut0_stack_3->SetBinError(37,13582.6);
   FullDY_muon1Pt_Cut0_stack_3->SetBinError(38,12879.67);
   FullDY_muon1Pt_Cut0_stack_3->SetBinError(39,13092.07);
   FullDY_muon1Pt_Cut0_stack_3->SetBinError(40,12215.17);
   FullDY_muon1Pt_Cut0_stack_3->SetBinError(41,43107.44);
   FullDY_muon1Pt_Cut0_stack_3->SetEntries(164408);
   FullDY_muon1Pt_Cut0_stack_3->SetDirectory(0);

   ci = TColor::GetColor("#ffcc00");
   FullDY_muon1Pt_Cut0_stack_3->SetFillColor(ci);

   ci = TColor::GetColor("#ffcc00");
   FullDY_muon1Pt_Cut0_stack_3->SetLineColor(ci);
   FullDY_muon1Pt_Cut0_stack_3->SetLineWidth(2);
   FullDY_muon1Pt_Cut0_stack_3->GetXaxis()->SetTitle("p_{T}(#mu_{1}) [GeV]");
   FullDY_muon1Pt_Cut0_stack_3->GetXaxis()->SetLabelFont(42);
   FullDY_muon1Pt_Cut0_stack_3->GetXaxis()->SetLabelOffset(0.007);
   FullDY_muon1Pt_Cut0_stack_3->GetXaxis()->SetLabelSize(0.05);
   FullDY_muon1Pt_Cut0_stack_3->GetXaxis()->SetTitleSize(0.06);
   FullDY_muon1Pt_Cut0_stack_3->GetXaxis()->SetTitleOffset(0.9);
   FullDY_muon1Pt_Cut0_stack_3->GetXaxis()->SetTitleFont(42);
   FullDY_muon1Pt_Cut0_stack_3->GetYaxis()->SetLabelFont(42);
   FullDY_muon1Pt_Cut0_stack_3->GetYaxis()->SetLabelOffset(0.007);
   FullDY_muon1Pt_Cut0_stack_3->GetYaxis()->SetLabelSize(0.05);
   FullDY_muon1Pt_Cut0_stack_3->GetYaxis()->SetTitleSize(0.06);
   FullDY_muon1Pt_Cut0_stack_3->GetYaxis()->SetTitleOffset(1.25);
   FullDY_muon1Pt_Cut0_stack_3->GetYaxis()->SetTitleFont(42);
   FullDY_muon1Pt_Cut0_stack_3->GetZaxis()->SetLabelFont(42);
   FullDY_muon1Pt_Cut0_stack_3->GetZaxis()->SetLabelOffset(0.007);
   FullDY_muon1Pt_Cut0_stack_3->GetZaxis()->SetLabelSize(0.05);
   FullDY_muon1Pt_Cut0_stack_3->GetZaxis()->SetTitleSize(0.06);
   FullDY_muon1Pt_Cut0_stack_3->GetZaxis()->SetTitleFont(42);
   Stack_muon1Pt_Cut0->Add(FullDY_muon1Pt_Cut0_stack_3,"");
   //Stack_muon1Pt_Cut0->Draw("hist");
   
   TH1F *Signal_muon1Pt_Cut0__1 = new TH1F("Signal_muon1Pt_Cut0__1","",40,0,80);
   Signal_muon1Pt_Cut0__1->SetBinContent(2,876.0918);
   Signal_muon1Pt_Cut0__1->SetBinContent(3,4108.832);
   Signal_muon1Pt_Cut0__1->SetBinContent(4,4927.538);
   Signal_muon1Pt_Cut0__1->SetBinContent(5,7402.784);
   Signal_muon1Pt_Cut0__1->SetBinContent(6,9315.648);
   Signal_muon1Pt_Cut0__1->SetBinContent(7,9373.034);
   Signal_muon1Pt_Cut0__1->SetBinContent(8,9503.109);
   Signal_muon1Pt_Cut0__1->SetBinContent(9,8929.25);
   Signal_muon1Pt_Cut0__1->SetBinContent(10,8451.034);
   Signal_muon1Pt_Cut0__1->SetBinContent(11,8083.764);
   Signal_muon1Pt_Cut0__1->SetBinContent(12,7387.481);
   Signal_muon1Pt_Cut0__1->SetBinContent(13,6786.842);
   Signal_muon1Pt_Cut0__1->SetBinContent(14,5922.228);
   Signal_muon1Pt_Cut0__1->SetBinContent(15,4965.795);
   Signal_muon1Pt_Cut0__1->SetBinContent(16,4422.542);
   Signal_muon1Pt_Cut0__1->SetBinContent(17,3940.5);
   Signal_muon1Pt_Cut0__1->SetBinContent(18,3638.268);
   Signal_muon1Pt_Cut0__1->SetBinContent(19,3029.977);
   Signal_muon1Pt_Cut0__1->SetBinContent(20,2899.902);
   Signal_muon1Pt_Cut0__1->SetBinContent(21,2264.831);
   Signal_muon1Pt_Cut0__1->SetBinContent(22,2096.499);
   Signal_muon1Pt_Cut0__1->SetBinContent(23,2077.37);
   Signal_muon1Pt_Cut0__1->SetBinContent(24,1733.055);
   Signal_muon1Pt_Cut0__1->SetBinContent(25,1438.474);
   Signal_muon1Pt_Cut0__1->SetBinContent(26,1381.088);
   Signal_muon1Pt_Cut0__1->SetBinContent(27,1078.855);
   Signal_muon1Pt_Cut0__1->SetBinContent(28,925.8262);
   Signal_muon1Pt_Cut0__1->SetBinContent(29,845.486);
   Signal_muon1Pt_Cut0__1->SetBinContent(30,638.8966);
   Signal_muon1Pt_Cut0__1->SetBinContent(31,600.6393);
   Signal_muon1Pt_Cut0__1->SetBinContent(32,516.4733);
   Signal_muon1Pt_Cut0__1->SetBinContent(33,508.8219);
   Signal_muon1Pt_Cut0__1->SetBinContent(34,455.2617);
   Signal_muon1Pt_Cut0__1->SetBinContent(35,382.5728);
   Signal_muon1Pt_Cut0__1->SetBinContent(36,317.5355);
   Signal_muon1Pt_Cut0__1->SetBinContent(37,294.5811);
   Signal_muon1Pt_Cut0__1->SetBinContent(38,233.3694);
   Signal_muon1Pt_Cut0__1->SetBinContent(39,153.0291);
   Signal_muon1Pt_Cut0__1->SetBinContent(40,210.4151);
   Signal_muon1Pt_Cut0__1->SetBinContent(41,1763.661);
   Signal_muon1Pt_Cut0__1->SetBinError(2,57.89377);
   Signal_muon1Pt_Cut0__1->SetBinError(3,125.3765);
   Signal_muon1Pt_Cut0__1->SetBinError(4,137.3005);
   Signal_muon1Pt_Cut0__1->SetBinError(5,168.2886);
   Signal_muon1Pt_Cut0__1->SetBinError(6,188.7833);
   Signal_muon1Pt_Cut0__1->SetBinError(7,189.3639);
   Signal_muon1Pt_Cut0__1->SetBinError(8,190.6733);
   Signal_muon1Pt_Cut0__1->SetBinError(9,184.8266);
   Signal_muon1Pt_Cut0__1->SetBinError(10,179.8092);
   Signal_muon1Pt_Cut0__1->SetBinError(11,175.8587);
   Signal_muon1Pt_Cut0__1->SetBinError(12,168.1145);
   Signal_muon1Pt_Cut0__1->SetBinError(13,161.1354);
   Signal_muon1Pt_Cut0__1->SetBinError(14,150.5219);
   Signal_muon1Pt_Cut0__1->SetBinError(15,137.8324);
   Signal_muon1Pt_Cut0__1->SetBinError(16,130.0748);
   Signal_muon1Pt_Cut0__1->SetBinError(17,122.7814);
   Signal_muon1Pt_Cut0__1->SetBinError(18,117.9789);
   Signal_muon1Pt_Cut0__1->SetBinError(19,107.6655);
   Signal_muon1Pt_Cut0__1->SetBinError(20,105.3292);
   Signal_muon1Pt_Cut0__1->SetBinError(21,93.08399);
   Signal_muon1Pt_Cut0__1->SetBinError(22,89.558);
   Signal_muon1Pt_Cut0__1->SetBinError(23,89.1485);
   Signal_muon1Pt_Cut0__1->SetBinError(24,81.42602);
   Signal_muon1Pt_Cut0__1->SetBinError(25,74.18362);
   Signal_muon1Pt_Cut0__1->SetBinError(26,72.68884);
   Signal_muon1Pt_Cut0__1->SetBinError(27,64.2449);
   Signal_muon1Pt_Cut0__1->SetBinError(28,59.51437);
   Signal_muon1Pt_Cut0__1->SetBinError(29,56.87354);
   Signal_muon1Pt_Cut0__1->SetBinError(30,49.43931);
   Signal_muon1Pt_Cut0__1->SetBinError(31,47.93624);
   Signal_muon1Pt_Cut0__1->SetBinError(32,44.45095);
   Signal_muon1Pt_Cut0__1->SetBinError(33,44.12045);
   Signal_muon1Pt_Cut0__1->SetBinError(34,41.73377);
   Signal_muon1Pt_Cut0__1->SetBinError(35,38.25728);
   Signal_muon1Pt_Cut0__1->SetBinError(36,34.85404);
   Signal_muon1Pt_Cut0__1->SetBinError(37,33.57063);
   Signal_muon1Pt_Cut0__1->SetBinError(38,29.87989);
   Signal_muon1Pt_Cut0__1->SetBinError(39,24.19603);
   Signal_muon1Pt_Cut0__1->SetBinError(40,28.37236);
   Signal_muon1Pt_Cut0__1->SetBinError(41,82.14187);
   Signal_muon1Pt_Cut0__1->SetMinimum(553.987);
   Signal_muon1Pt_Cut0__1->SetMaximum(1.094493e+09);
   Signal_muon1Pt_Cut0__1->SetEntries(34995);
   Signal_muon1Pt_Cut0__1->SetDirectory(0);

   ci = TColor::GetColor("#33ff00");
   Signal_muon1Pt_Cut0__1->SetFillColor(ci);
   Signal_muon1Pt_Cut0__1->SetFillStyle(0);

   ci = TColor::GetColor("#33ff00");
   Signal_muon1Pt_Cut0__1->SetLineColor(ci);
   Signal_muon1Pt_Cut0__1->SetLineWidth(2);
   Signal_muon1Pt_Cut0__1->GetXaxis()->SetTitle("p_{T}(#mu_{1}) [GeV]");
   Signal_muon1Pt_Cut0__1->GetXaxis()->SetLabelFont(42);
   Signal_muon1Pt_Cut0__1->GetXaxis()->SetLabelOffset(0.007);
   Signal_muon1Pt_Cut0__1->GetXaxis()->SetLabelSize(0.05);
   Signal_muon1Pt_Cut0__1->GetXaxis()->SetTitleSize(0.06);
   Signal_muon1Pt_Cut0__1->GetXaxis()->SetTitleOffset(0.9);
   Signal_muon1Pt_Cut0__1->GetXaxis()->SetTitleFont(42);
   Signal_muon1Pt_Cut0__1->GetYaxis()->SetLabelFont(42);
   Signal_muon1Pt_Cut0__1->GetYaxis()->SetLabelOffset(0.007);
   Signal_muon1Pt_Cut0__1->GetYaxis()->SetLabelSize(0.05);
   Signal_muon1Pt_Cut0__1->GetYaxis()->SetTitleSize(0.06);
   Signal_muon1Pt_Cut0__1->GetYaxis()->SetTitleOffset(1.25);
   Signal_muon1Pt_Cut0__1->GetYaxis()->SetTitleFont(42);
   Signal_muon1Pt_Cut0__1->GetZaxis()->SetLabelFont(42);
   Signal_muon1Pt_Cut0__1->GetZaxis()->SetLabelOffset(0.007);
   Signal_muon1Pt_Cut0__1->GetZaxis()->SetLabelSize(0.05);
   Signal_muon1Pt_Cut0__1->GetZaxis()->SetTitleSize(0.06);
   Signal_muon1Pt_Cut0__1->GetZaxis()->SetTitleFont(42);

// %%
Signal_muon1Pt_Cut0__1->SetStats(0);
Signal_muon1Pt_Cut0__1->Draw("hist");
Stack_muon1Pt_Cut0->Draw("hist same");
Signal_muon1Pt_Cut0__1->Draw("hist same");
 redrawBorder();

// %%
Canvas_muon1Pt_Cut0->Draw()
